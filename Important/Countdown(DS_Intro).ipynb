# %%
import time
import datetime
print("Merhaba Geleceğin VERİ BİLİMCİLERİ!!!\n(Geri Sayımdan çıkmak için 'Interrupt')\n")
try: 
    def countdown(stop):
        while True:
            difference = stop - datetime.datetime.now()
            count_hours, rem = divmod(difference.seconds, 3600)
            count_minutes, count_seconds = divmod(rem, 60)
            print('DATA SCIENCE Introya '
                  + str(difference.days) + " gün "
                  + str(count_hours) + " saat "
                  + str(count_minutes) + " dakika "
                  + str(count_seconds) + " saniye kaldı "
                  )
            time.sleep(1)
    end_time = datetime.datetime(2021, 12, 17, 21, 30, 0)
    countdown(end_time)
    
except KeyboardInterrupt:
    print('\n17 Aralık Cuma 21.30 (TR) de görüşmek üzere...')
# Out:
# Merhaba Geleceğin VERİ BİLİMCİLERİ!!!
# (Geri Sayımdan çıkmak için 'Interrupt')
#
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 39 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 38 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 37 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 36 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 35 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 34 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 33 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 32 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 31 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 30 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 29 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 28 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 27 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 26 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 25 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 24 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 23 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 22 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 21 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 20 saniye kaldı
# DATA SCIENCE Introya 1 gün 8 saat 42 dakika 19 saniye kaldı
#
# 17 Aralık Cuma 21.30 (TR) de görüşmek üzere...
